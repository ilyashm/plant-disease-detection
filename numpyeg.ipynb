# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyashm/plant-disease-detection/blob/main/numpyeg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data=np.array([[1,2,3],[2,3,4]])
print(data)
# Out:
# [[1 2 3]
#  [2 3 4]]

# %%
print(data.T)
# Out:
# [[1 2]
#  [2 3]
#  [3 4]]

# %%
for i in np.nditer(data):
  print(i)
# Out:
# 1
# 2
# 3
# 2
# 3
# 4

# %%
for i in np.nditer(data):
  if(i==3):
    break;
  print(i)
# Out:
# 1
# 2

# %%
import pandas as pd
data = [1,2,3,4,5]
s = pd.Series(data)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data = ["grapes","kivy","banana","orange"]
s = pd.Series(data)
print(s)
# Out:
# 0    grapes
# 1      kivy
# 2    banana
# 3    orange
# dtype: object

# %%
d= np.array([1,2,3])
k=pd.Series(d)
print(k)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
dict={"ilyas":39, "rosh":42}
print(dict)
p=pd.Series(dict)
print(p)
# Out:
# {'ilyas': 39, 'rosh': 42}
# ilyas    39
# rosh     42
# dtype: int64

# %%
m=pd.Series(dict,index=['ilyas'])
print(m)
# Out:
# ilyas    39
# dtype: int64

# %%
m=pd.Series(dict,index=['ilyas','rosh','ilyas'])
print(m)
# Out:
# ilyas    39
# rosh     42
# ilyas    39
# dtype: int64

# %%
s = pd.Series(["grapes","kivy","banana","orange"],index=['a','b','c','d'])
print(s)
# Out:
# a    grapes
# b      kivy
# c    banana
# d    orange
# dtype: object

# %%
#Importing the libraries
import numpy as np
import pandas as pd
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
print(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
boston = pd.read_csv("Boston.csv")
print(boston)
# Out:
#      Unnamed: 0     crim    zn  indus  chas  ...  tax  ptratio   black  lstat  medv
# 0             1  0.00632  18.0   2.31     0  ...  296     15.3  396.90   4.98  24.0
# 1             2  0.02731   0.0   7.07     0  ...  242     17.8  396.90   9.14  21.6
# 2             3  0.02729   0.0   7.07     0  ...  242     17.8  392.83   4.03  34.7
# 3             4  0.03237   0.0   2.18     0  ...  222     18.7  394.63   2.94  33.4
# 4             5  0.06905   0.0   2.18     0  ...  222     18.7  396.90   5.33  36.2
# ..          ...      ...   ...    ...   ...  ...  ...      ...     ...    ...   ...
# 501         502  0.06263   0.0  11.93     0  ...  273     21.0  391.99   9.67  22.4
# 502         503  0.04527   0.0  11.93     0  ...  273     21.0  396.90   9.08  20.6
# 503         504  0.06076   0.0  11.93     0  ...  273     21.0  396.90   5.64  23.9
# 504         505  0.10959   0.0  11.93     0  ...  273     21.0  393.45   6.48  22.0
# ...

# %%
boston = pd.read_csv("/content/sample_data/california_housing_train.csv")
print(boston)
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 0        -114.31     34.19  ...         1.4936             66900.0
# 1        -114.47     34.40  ...         1.8200             80100.0
# 2        -114.56     33.69  ...         1.6509             85700.0
# 3        -114.57     33.64  ...         3.1917             73400.0
# 4        -114.57     33.57  ...         1.9250             65500.0
# ...          ...       ...  ...            ...                 ...
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
print(boston.describe)
# Out:
# <bound method NDFrame.describe of        longitude  latitude  ...  median_income  median_house_value
# 0        -114.31     34.19  ...         1.4936             66900.0
# 1        -114.47     34.40  ...         1.8200             80100.0
# 2        -114.56     33.69  ...         1.6509             85700.0
# 3        -114.57     33.64  ...         3.1917             73400.0
# 4        -114.57     33.57  ...         1.9250             65500.0
# ...          ...       ...  ...            ...                 ...
# 16995    -124.26     40.58  ...         2.3571            111400.0
# 16996    -124.27     40.69  ...         2.5179             79000.0
# 16997    -124.30     41.84  ...         3.0313            103600.0
# 16998    -124.30     41.80  ...         1.9797             85800.0
# 16999    -124.35     40.54  ...         3.0147             94600.0
#
# [17000 rows x 9 columns]>

# %%
data = pd.DataFrame(boston.data)
print(data)
# Out:
#           0     1      2    3      4   ...   8      9     10      11    12
# 0    0.00632  18.0   2.31  0.0  0.538  ...  1.0  296.0  15.3  396.90  4.98
# 1    0.02731   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  396.90  9.14
# 2    0.02729   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  392.83  4.03
# 3    0.03237   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  394.63  2.94
# 4    0.06905   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  396.90  5.33
# ..       ...   ...    ...  ...    ...  ...  ...    ...   ...     ...   ...
# 501  0.06263   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  391.99  9.67
# 502  0.04527   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  9.08
# 503  0.06076   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  5.64
# 504  0.10959   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  393.45  6.48
# 505  0.04741   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  7.88
#
# [506 rows x 13 columns]

# %%
print("Shape of data set - ",data.shape)
print("head:",data.head)
print("tail:",data.tail(10))
print("Description:",data.describe)
# Out:
# Shape of data set -  (506, 13)
# head: <bound method NDFrame.head of           0     1      2    3      4   ...   8      9     10      11    12
# 0    0.00632  18.0   2.31  0.0  0.538  ...  1.0  296.0  15.3  396.90  4.98
# 1    0.02731   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  396.90  9.14
# 2    0.02729   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  392.83  4.03
# 3    0.03237   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  394.63  2.94
# 4    0.06905   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  396.90  5.33
# ..       ...   ...    ...  ...    ...  ...  ...    ...   ...     ...   ...
# 501  0.06263   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  391.99  9.67
# 502  0.04527   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  9.08
# 503  0.06076   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  5.64
# 504  0.10959   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  393.45  6.48
# 505  0.04741   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  7.88
#
# ...

# %%
data.columns = boston.feature_names
print(data.columns)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
# Create a target variable
data['PRICE'] = boston.target
print(data['PRICE'])
print(data.columns)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'PRICE'],
#       dtype='object')

# %%
corr=data.corr()
print(corr)
print("Corr Shape:",corr.shape)
# Out:
#              CRIM        ZN     INDUS  ...         B     LSTAT     PRICE
# CRIM     1.000000 -0.200469  0.406583  ... -0.385064  0.455621 -0.388305
# ZN      -0.200469  1.000000 -0.533828  ...  0.175520 -0.412995  0.360445
# INDUS    0.406583 -0.533828  1.000000  ... -0.356977  0.603800 -0.483725
# CHAS    -0.055892 -0.042697  0.062938  ...  0.048788 -0.053929  0.175260
# NOX      0.420972 -0.516604  0.763651  ... -0.380051  0.590879 -0.427321
# RM      -0.219247  0.311991 -0.391676  ...  0.128069 -0.613808  0.695360
# AGE      0.352734 -0.569537  0.644779  ... -0.273534  0.602339 -0.376955
# DIS     -0.379670  0.664408 -0.708027  ...  0.291512 -0.496996  0.249929
# RAD      0.625505 -0.311948  0.595129  ... -0.444413  0.488676 -0.381626
# TAX      0.582764 -0.314563  0.720760  ... -0.441808  0.543993 -0.468536
# PTRATIO  0.289946 -0.391679  0.383248  ... -0.177383  0.374044 -0.507787
# B       -0.385064  0.175520 -0.356977  ...  1.000000 -0.366087  0.333461
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':15}, cmap='Reds')
plt.show()

# %%
X=data.drop('PRICE',axis=1)
print(X)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %%
y=data['PRICE']
print(y)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3, random_state=4 )
